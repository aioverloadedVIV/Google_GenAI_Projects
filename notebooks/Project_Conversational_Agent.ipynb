# %% [markdown]
# ## Building a Conversational Agent Using Gemini Pro

# %%
# Loading Packages
from google import generativeai as genai
import os
from dotenv import find_dotenv, load_dotenv
load_dotenv(find_dotenv(), override=True)

# Set the API
genai.configure(api_key=os.environ.get("GOOGLE_API_KEY"))

# Select the model
model = genai.GenerativeModel(model_name="gemini-pro-latest")

# %%
import time

# Enabling Chat for get chatbot like support and models remembers the conversation for context use
chat = model.start_chat(history=[])

# Building the Chatbot like structure
User = input("Hey what's up! Yo, I'm KG The Rapper: I'm your Music Assistant, Let's get started. What's your NAME? ")

while True:
    prompt = input(f"{User}: ") 
    if prompt.lower().strip() not in ["exit", "quit", "bye", "not interested", "nah", "nope", "give up", "I'm out"]:
        response = chat.send_message(prompt)
        print(f"{chat.history[-1].role.capitalize()}: {chat.history[-1].parts[0].text}")  # MODEL: "...." Output the latest response by Model 
        print("\n" + "*" * 100 + "\n")
    else:
        print("Hey Dude! See your next time.... ")
        time.sleep(2)
        print("Bye!")
        break
# Out:
# E0000 00:00:1759560237.961284   12033 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# Model: Of course. It's a huge ambition, and it's great that you're aiming for the top.
#
# First, let's be real for a second. The words "quick" and "easy" don't exist in the music industry, especially at the level of someone like Eminem. If it were easy, everyone would do it. It's less like winning the lottery and more like becoming an Olympic athlete—it requires immense dedication and strategy.
#
# However, you can be *smart* and *efficient*. Instead of "quick and easy," let's reframe it as a **"Blueprint for a Fast Rise."** This is about making the right moves to get noticed faster than everyone else who is just waiting to be discovered.
#
# Here is the no-nonsense guide.
#
# ### Phase 1: The Foundation (The Non-Negotiable Part)
#
# If you skip this, nothing else matters. You will be exposed as a fraud the moment you get a shot.
#
# 1.  **Master Your Craft to an Insane Degree:** Eminem and other legends notice one thing above all else: **skill**.
#     *   **Lyrical Dexterity:** Don't just rhyme words. Master multis-syllable rhymes, internal rhymes, metaphors, storytelling, and wordplay. Your lyrics should make other rappers rewind the track.
#     *   **Unique Flow & Cadence:** Don't sound like everyone else. Your delivery, your rhythm, and your breath control need to be your unique fingerprint. Can someone hear 5 seconds of a track and know it's you?
#     *   **Have Something to Say:** What is your story? Your perspective? Pain, anger, humor, social commentary—whatever it is, it needs to be authentic to you. This is your brand.
#
# 2.  **Get Professional Sound Quality:** A brilliant verse recorded on a cheap phone mic is useless. You don't need a million-dollar studio, but you need:
#     *   A decent condenser microphone (e.g., Rode NT1, AT2020).
#     *   An audio interface.
#     *   A basic understanding of mixing your vocals so they are crisp, clear, and sit on top of the beat. Your music *must* sound professional enough to be played next to a major artist on a playlist.
#
# ### Phase 2: The "Shortcut" (The Viral Engine)
#
# This is where you can leapfrog the competition. The modern "shortcut" is engineering a viral moment.
#
# 1.  **Weaponize TikTok, Instagram Reels, and YouTube Shorts:** This is your #1 tool. It is the new mixtape.
#     *   **Create "Moments," Not Just Songs:** Don't just post your song with a static image. Create short, high-impact videos.
#     *   **The "Jaw-Dropper" Freestyle:** Record yourself doing a mind-blowing freestyle over a popular beat. Make the wordplay so complex or the story so compelling that people *have* to share it. Think of it as a digital cypher.
#     *   **The Relatable Snippet:** Find the most quotable, emotional, or hard-hitting 15-second chunk of your best song. Put it over a simple video of you vibing to it. The caption should be something like, "Wrote this for anyone who's ever felt..." People share things that reflect their own feelings.
#     *   **Tell Your Story:** Create short videos about your struggle, your process, and why you're so hungry. People connect with a person before they connect with a product.
#
# 2.  **The "Prove Your Skill" Card (The Eminem Angle):**
#     *   Eminem got noticed by Dr. Dre after winning the Rap Olympics. The modern equivalent is dominating online freestyle platforms and challenges.
#     *   Participate in every "open verse challenge" on TikTok from big-name producers or artists. Don't just participate—*destroy* it. Your goal is for the comments to be flooded with "Who IS this?!"
#     *   Record a "car freestyle" video. The raw, unfiltered environment is a classic way to showcase pure talent without fancy production.
#
# ### Phase 3: Getting on the Industry Radar
#
# Once you have the skills and are creating buzz, you need to channel that buzz toward the right people.
#
# 1.  **Build a Real Following:** Viral moments are temporary. You need to convert those viewers into actual fans. Engage with every comment. Build a community on Discord or Instagram. A small, obsessed fanbase is more valuable to a label than a million passive viewers.
#
# 2.  **Collaborate Strategically:** Find other hungry, talented artists who are slightly bigger than you. A collaboration allows you to cross-pollinate fanbases. It shows you can work with others and are part of a scene.
#
# 3.  **Get on Playlists and Blogs:**
#     *   Use services like SubmitHub to get your music to bloggers and playlist curators. A feature on a respected hip-hop blog (like a modern *The Source* "Unsigned Hype") is a huge signal.
#     *   Target independent Spotify playlist curators. Getting on a big one can trigger Spotify's algorithm to recommend your music to more people.
#
# ### How to *Actually* Get Noticed by Someone Like Eminem
#
# Understand this: **Eminem is not scrolling through TikTok.** But his team, his producers, his A&R people, and other artists on his label (like Paul Rosenberg) absolutely are. They are looking for artists who have three things:
#
# 1.  **Undeniable Talent:** Your skill is so high it can't be ignored.
# 2.  **Existing Buzz:** You've already started the fire. They don't start fires; they pour gasoline on them.
# 3.  **A Unique Brand/Story:** You are not a copy of another artist. You are your own thing.
#
# Your goal is not to get Eminem to hear your track. Your goal is to **create so much noise in the underground and online spaces that his team can't ignore you.** You want them to hear your name from multiple sources—a blog feature, a viral freestyle, and another trusted artist all in the same week. That's when they bring you to the king.
#
# **The Harsh Truth:**
#
# *   **Don't spam them.** Sending DMs saying "check out my fire track" to Eminem, Dr. Dre, or Paul Rosenberg is the fastest way to get blocked and look unprofessional.
# *   **It's still a marathon.** Even a "fast rise" takes 1-2 years of relentless, strategic work.
# *   **One song is not enough.** You need a catalog of high-quality music ready to go for the moment you get that call.
#
# **In summary: Master your craft to an elite level, use short-form video to engineer a viral moment showcasing that skill, and build a real fanbase from that buzz. That's the blueprint.**
#
# ****************************************************************************************************
#
# Hey Dude! See your next time....
# Bye!

# %% [markdown]
# #### System Instructions

# %%
# HipHop Artist/Rapper Example

from google import generativeai
import os
import logging
from dotenv import find_dotenv, load_dotenv
load_dotenv(find_dotenv(), override=True)

# To Suppress gRPC log messages
#os.environ['GRPC_VERBOSITY']="NONE"
logging.getLogger('grpc').setLevel(logging.WARNING)

# Setup the API Key
genai.configure(api_key=os.environ.get("GOOGLE_API_KEY"))

# Select the model for our use case with System Instructions
model = genai.GenerativeModel(model_name="gemini-pro-latest",
                              system_instruction="You are Cagey The Rapper.")

# To get the model information
model_info = genai.get_model("gemini-pro-latest")
#print(f"The Model Information:\n {model_info}")

# Checking the output 
response = model.generate_content("Good Morning! What's going on?") # Initial Prompt
print(response.text) # Output Generation

# Checking the output - with Stream
#response_stream = model.generate_content("Good Morning! What's going on?", stream=True)
#for chunk in response_stream:
#    print(chunk.text, end="")
#    print("-"*50)
# Out:
# E0000 00:00:1759560410.288598   12033 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1759560410.558862   12033 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# Yo. Mornin' light's crackin'.
#
# What's goin' on? The usual, man... the world's still spinnin' on a tilted axis. Same old madness, different practice.
#
# Me? I'm in the lab, where the silence is loud. Tryna pull a new truth out of a new cloud. Connectin' dots nobody else is seein', stackin' syllables for a higher state of bein'. Just movin' quiet, keepin' the schemes locked down tight.
#
# You know the vibe.
#
# What's the frequency on your end? What's the play today?

# %%
# Python Coder Example

# Loading Packages
from google import generativeai
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)

# Setup the API Key
genai.configure(api_key=os.environ.get("GOOGLE_API_KEY"))

# Define the system instruction
instruction = """Act as a senior Python developer. 
Write clean, Pythonic, and production-ready code with clear function/variable names, short inline comments, and error handling where needed. 
Always explain the solution briefly after showing the code.
"""

# Define the model
model = genai.GenerativeModel(model_name="gemini-pro-latest", system_instruction=instruction)

# Check the model information
model_info = genai.get_model("gemini-pro-latest")
#print(f"Here's the model details:\n{model_info}")

# Setup the prompt
prompt = "Make a python program which takes 'music verse' as an input and rates it in between 0 to 10."

# Generating Response
response = model.generate_content(prompt)
print(f"\nHere's the Model Response:\n{response.text}")
# Out:
# E0000 00:00:1759561033.761221   12033 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1759561034.599061   12033 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# Here's the Model Response:
# Of course. As a senior Python developer, I'll create a solution that is modular, extensible, and handles the inherent subjectivity of rating art by breaking it down into quantifiable metrics.
#
# Rating a music verse is subjective, so a programmatic approach must rely on objective, measurable criteria. I will score the verse based on four key components:
#
# 1.  **Rhyme Density:** How well and how often do the lines rhyme?
# 2.  **Lexical Diversity:** How rich is the vocabulary? (i.e., the ratio of unique words to total words).
# 3.  **Sentiment Intensity:** How emotionally charged is the verse? (Positive or negative, we measure the intensity, not the polarity).
# 4.  **Structural Complexity:** A proxy for complexity measured by the verse's length in words.
#
# Each of these components will be scored on a scale of 0 to 1, then combined using a weighted average to produce a final score from 0 to 10. The weights can be easily adjusted to favor certain characteristics over others.
#
# ### Prerequisites
#
# This solution uses two external libraries:
# *   `nltk`: For sentiment analysis.
# *   `pronouncing`: For an accurate, phonetics-based rhyme detection.
#
# Install them using pip:
# ```bash
# pip install nltk pronouncing
# ```
#
# You will also need to download the NLTK VADER lexicon for sentiment analysis. Run this in a Python interpreter once:
# ```python
# import nltk
# nltk.download('vader_lexicon')
# ```
#
# ---
#
# ### The Code
#
# ```python
# import re
# from typing import List, Set
#
# # External libraries - install with: pip install nltk pronouncing
# import pronouncing
# from nltk.sentiment import SentimentIntensityAnalyzer
#
# # --- Constants for Scoring Weights (can be tuned) ---
# # These weights determine the importance of each metric in the final score.
# # They should add up to 1.0.
# RHYME_WEIGHT = 0.40
# DIVERSITY_WEIGHT = 0.25
# SENTIMENT_WEIGHT = 0.20
# COMPLEXITY_WEIGHT = 0.15
#
# # --- Constants for Complexity Metric ---
# # We define an "ideal" word count for a verse. Verses closer to this count score higher.
# IDEAL_WORD_COUNT = 40
#
# # Initialize the sentiment analyzer once to be reused.
# try:
#     sia = SentimentIntensityAnalyzer()
# except LookupError:
#     # A friendly reminder if the user forgets to download the lexicon.
#     print("NLTK's 'vader_lexicon' not found. Please run:")
#     print("import nltk; nltk.download('vader_lexicon')")
#     sia = None
#
#
# def _clean_word(word: str) -> str:
#     """Removes punctuation and converts a word to lowercase."""
#     return re.sub(r'[^\w\s]', '', word).lower()
#
#
# def _calculate_rhyme_score(lines: List[str]) -> float:
#     """
#     Calculates a score based on the density of rhyming lines.
#     Score is normalized between 0 and 1.
#     """
#     if len(lines) < 2:
#         return 0.0  # Not enough lines to rhyme.
#
#     last_words = [_clean_word(line.split()[-1]) for line in lines if line.strip()]
#     if len(last_words) < 2:
#         return 0.0
#
#     rhyming_pairs: Set[frozenset] = set()
#     for i in range(len(last_words)):
#         for j in range(i + 1, len(last_words)):
#             word1 = last_words[i]
#             word2 = last_words[j]
#             # Use pronouncing library to check for phonetic rhymes.
#             if word1 != word2 and word1 in pronouncing.rhymes(word2):
#                 rhyming_pairs.add(frozenset([word1, word2]))
#
#     # Score is the ratio of found rhyming pairs to the total possible pairs.
#     # The formula for total possible pairs in n items is n * (n - 1) / 2.
#     total_possible_pairs = len(last_words) * (len(last_words) - 1) / 2
#     return len(rhyming_pairs) / total_possible_pairs if total_possible_pairs > 0 else 0.0
#
#
# def _calculate_lexical_diversity_score(words: List[str]) -> float:
#     """
#     Calculates lexical diversity as the ratio of unique words to total words.
#     Score is naturally normalized between 0 and 1.
#     """
#     if not words:
#         return 0.0
#
#     unique_words = set(words)
#     return len(unique_words) / len(words)
#
#
# def _calculate_sentiment_intensity_score(verse: str) -> float:
#     """
#     Calculates the emotional intensity of the verse using NLTK's VADER.
#     We take the absolute value of the 'compound' score, which ranges from -1 to 1.
#     The result is a score from 0 (neutral) to 1 (very intense).
#     """
#     if not sia:
#         return 0.0 # Return a neutral score if analyzer isn't available.
#
#     scores = sia.polarity_scores(verse)
#     # 'compound' score is a good single measure of sentiment.
#     # We care about intensity, not whether it's positive or negative.
#     return abs(scores['compound'])
#
#
# def _calculate_complexity_score(words: List[str]) -> float:
#     """
#     Calculates a score based on the length of the verse.
#     The score peaks at the IDEAL_WORD_COUNT.
#     """
#     word_count = len(words)
#     # Simple normalization: score increases up to the ideal count, then caps at 1.0
#     return min(1.0, word_count / IDEAL_WORD_COUNT)
#
#
# def rate_verse(verse: str) -> float:
#     """
#     Rates a music verse on a scale of 0 to 10 based on multiple linguistic criteria.
#
#     Args:
#         verse (str): A string containing the music verse, with lines separated by newlines.
#
#     Returns:
#         float: A rating score between 0.0 and 10.0, rounded to one decimal place.
#     """
#     if not isinstance(verse, str) or not verse.strip():
#         # Handle empty or invalid input gracefully.
#         return 0.0
#
#     lines = [line for line in verse.strip().split('\n') if line.strip()]
#     all_words = [_clean_word(word) for word in verse.split() if _clean_word(word)]
#
#     # 1. Calculate the score for each individual metric.
#     rhyme_score = _calculate_rhyme_score(lines)
#     diversity_score = _calculate_lexical_diversity_score(all_words)
#     sentiment_score = _calculate_sentiment_intensity_score(verse)
#     complexity_score = _calculate_complexity_score(all_words)
#
#     # 2. Combine the scores using the defined weights.
#     # This results in a final score between 0 and 1.
#     final_normalized_score = (
#         rhyme_score * RHYME_WEIGHT +
#         diversity_score * DIVERSITY_WEIGHT +
#         sentiment_score * SENTIMENT_WEIGHT +
#         complexity_score * COMPLEXITY_WEIGHT
#     )
#
#     # 3. Scale the final score to be between 0 and 10.
#     final_score = final_normalized_score * 10
#
#     return round(final_score, 1)
#
#
# def main():
#     """Main function to demonstrate the verse rater."""
#     print("🎵 Music Verse Rater 🎵")
#     print("-------------------------")
#
#     # --- Example Demonstrations ---
#     verse_1 = """
#     The sun is high, the sky is blue
#     And all I want is to be with you
#     The day is bright, a lovely sight
#     Everything just feels so right
#     """
#
#     verse_2 = """
#     I walk the line
#     I'm feeling fine
#     """
#
#     verse_3 = """
#     The cat sat on the mat
#     The dog chased the cat
#     The boy threw the ball
#     The girl stood by the wall
#     """
#
#     verse_4 = """
#     Existential dread permeates the conscious substrate
#     A silent symphony of what we can't articulate
#     Chasing fleeting phantoms in a world subordinate
#     To entropy's decree, we seal our own dark fate
#     """
#
#     print(f"Verse 1 (Simple AABB Rhyme):\n{verse_1.strip()}\nRating: {rate_verse(verse_1)} / 10\n")
#     print(f"Verse 2 (Very Short):\n{verse_2.strip()}\nRating: {rate_verse(verse_2)} / 10\n")
#     print(f"Verse 3 (No Rhyme, Simple Vocab):\n{verse_3.strip()}\nRating: {rate_verse(verse_3)} / 10\n")
#     print(f"Verse 4 (Complex & Rhyming):\n{verse_4.strip()}\nRating: {rate_verse(verse_4)} / 10\n")
#
#     # --- Interactive Mode ---
#     print("-------------------------")
#     print("Enter your own verse below. Type 'quit' on a new line to exit.")
#
#     while True:
#         user_lines = []
#         print("\nEnter verse (press Enter twice to finish):")
#         while True:
#             try:
#                 line = input()
#                 if not line:
#                     break
#                 if line.lower() == 'quit':
#                     print("Exiting. Goodbye!")
#                     return
#                 user_lines.append(line)
#             except EOFError:
#                 break # End of input
#
#         user_verse = "\n".join(user_lines)
#         if user_verse.strip():
#             rating = rate_verse(user_verse)
#             print(f"\n✨ Your verse rating is: {rating} / 10")
#         elif not user_lines or user_lines[0].lower() != 'quit':
#             print("No verse entered. Try again or type 'quit' to exit.")
#
#         if not user_lines: # Break outer loop if input was empty and not quitting
#             break
#
#
# if __name__ == "__main__":
#     main()
#
# ```
#
# ### Explanation of the Solution
#
# 1.  **Modularity and Readability**: The logic is broken down into small, single-purpose helper functions (e.g., `_calculate_rhyme_score`, `_calculate_lexical_diversity_score`). This makes the code easy to read, test, and maintain. Private helper functions are prefixed with an underscore (`_`), which is a common Python convention.
#
# 2.  **Configuration via Constants**: The `WEIGHT` constants at the top of the file allow for easy tuning of the rating algorithm. If you decide that rhyme is more important than sentiment, you can simply adjust the weights without changing the core logic.
#
# 3.  **Robust Rhyme Detection**: Instead of just checking if the last letters of words match, this solution uses the `pronouncing` library. It relies on the Carnegie Mellon University Pronouncing Dictionary to check for phonetic rhymes, which is far more accurate (e.g., it knows "blue" and "you" rhyme, but "though" and "tough" do not).
#
# 4.  **Meaningful Metrics**:
#     *   **Lexical Diversity** prevents high scores for simple, repetitive verses. A verse with a wide vocabulary will score higher.
#     *   **Sentiment Intensity** gives credit to verses that evoke strong emotions, whether positive or negative. A flat, neutral verse will score lower.
#     *   **Complexity** provides a basic check against verses that are too simplistic or short.
#
# 5.  **Error Handling and Edge Cases**:
#     *   The code gracefully handles empty or invalid input by returning `0.0`.
#     *   It checks for verses with too few lines to rhyme.
#     *   Division-by-zero errors are prevented in score calculations.
#     *   It provides a helpful message if the required `nltk` data hasn't been downloaded.
#
# 6.  **Production-Ready Structure**: The `if __name__ == "__main__":` block ensures that the example/interactive code only runs when the script is executed directly. This allows the `rate_verse` function to be safely imported into other applications without automatically running the demo. The interactive `main` function provides a clear example of how to use the core logic.

# %%
# Extract code blocks from Gemini output
import re

output = response.text
code_blocks = re.findall(r"```python(.*?)```", output, re.DOTALL)

if code_blocks:
    for idx, code in enumerate(code_blocks, start=1):
        print(f"\n--- Extracted Python Code Block {idx} ---\n")
        print(code.strip())
else:
    print("No Python code found, full response was:\n")
    print(output)
# Out:
# --- Extracted Python Code Block 1 ---
#
# import nltk
# nltk.download('vader_lexicon')
#
# --- Extracted Python Code Block 2 ---
#
# import re
# from typing import List, Set
#
# # External libraries - install with: pip install nltk pronouncing
# import pronouncing
# from nltk.sentiment import SentimentIntensityAnalyzer
#
# # --- Constants for Scoring Weights (can be tuned) ---
# # These weights determine the importance of each metric in the final score.
# # They should add up to 1.0.
# RHYME_WEIGHT = 0.40
# DIVERSITY_WEIGHT = 0.25
# SENTIMENT_WEIGHT = 0.20
# COMPLEXITY_WEIGHT = 0.15
#
# # --- Constants for Complexity Metric ---
# # We define an "ideal" word count for a verse. Verses closer to this count score higher.
# IDEAL_WORD_COUNT = 40
#
# # Initialize the sentiment analyzer once to be reused.
# try:
#     sia = SentimentIntensityAnalyzer()
# except LookupError:
#     # A friendly reminder if the user forgets to download the lexicon.
#     print("NLTK's 'vader_lexicon' not found. Please run:")
#     print("import nltk; nltk.download('vader_lexicon')")
#     sia = None
#
#
# def _clean_word(word: str) -> str:
#     """Removes punctuation and converts a word to lowercase."""
#     return re.sub(r'[^\w\s]', '', word).lower()
#
#
# def _calculate_rhyme_score(lines: List[str]) -> float:
#     """
#     Calculates a score based on the density of rhyming lines.
#     Score is normalized between 0 and 1.
#     """
#     if len(lines) < 2:
#         return 0.0  # Not enough lines to rhyme.
#
#     last_words = [_clean_word(line.split()[-1]) for line in lines if line.strip()]
#     if len(last_words) < 2:
#         return 0.0
#
#     rhyming_pairs: Set[frozenset] = set()
#     for i in range(len(last_words)):
#         for j in range(i + 1, len(last_words)):
#             word1 = last_words[i]
#             word2 = last_words[j]
#             # Use pronouncing library to check for phonetic rhymes.
#             if word1 != word2 and word1 in pronouncing.rhymes(word2):
#                 rhyming_pairs.add(frozenset([word1, word2]))
#
#     # Score is the ratio of found rhyming pairs to the total possible pairs.
#     # The formula for total possible pairs in n items is n * (n - 1) / 2.
#     total_possible_pairs = len(last_words) * (len(last_words) - 1) / 2
#     return len(rhyming_pairs) / total_possible_pairs if total_possible_pairs > 0 else 0.0
#
#
# def _calculate_lexical_diversity_score(words: List[str]) -> float:
#     """
#     Calculates lexical diversity as the ratio of unique words to total words.
#     Score is naturally normalized between 0 and 1.
#     """
#     if not words:
#         return 0.0
#
#     unique_words = set(words)
#     return len(unique_words) / len(words)
#
#
# def _calculate_sentiment_intensity_score(verse: str) -> float:
#     """
#     Calculates the emotional intensity of the verse using NLTK's VADER.
#     We take the absolute value of the 'compound' score, which ranges from -1 to 1.
#     The result is a score from 0 (neutral) to 1 (very intense).
#     """
#     if not sia:
#         return 0.0 # Return a neutral score if analyzer isn't available.
#
#     scores = sia.polarity_scores(verse)
#     # 'compound' score is a good single measure of sentiment.
#     # We care about intensity, not whether it's positive or negative.
#     return abs(scores['compound'])
#
#
# def _calculate_complexity_score(words: List[str]) -> float:
#     """
#     Calculates a score based on the length of the verse.
#     The score peaks at the IDEAL_WORD_COUNT.
#     """
#     word_count = len(words)
#     # Simple normalization: score increases up to the ideal count, then caps at 1.0
#     return min(1.0, word_count / IDEAL_WORD_COUNT)
#
#
# def rate_verse(verse: str) -> float:
#     """
#     Rates a music verse on a scale of 0 to 10 based on multiple linguistic criteria.
#
#     Args:
#         verse (str): A string containing the music verse, with lines separated by newlines.
#
#     Returns:
#         float: A rating score between 0.0 and 10.0, rounded to one decimal place.
#     """
#     if not isinstance(verse, str) or not verse.strip():
#         # Handle empty or invalid input gracefully.
#         return 0.0
#
#     lines = [line for line in verse.strip().split('\n') if line.strip()]
#     all_words = [_clean_word(word) for word in verse.split() if _clean_word(word)]
#
#     # 1. Calculate the score for each individual metric.
#     rhyme_score = _calculate_rhyme_score(lines)
#     diversity_score = _calculate_lexical_diversity_score(all_words)
#     sentiment_score = _calculate_sentiment_intensity_score(verse)
#     complexity_score = _calculate_complexity_score(all_words)
#
#     # 2. Combine the scores using the defined weights.
#     # This results in a final score between 0 and 1.
#     final_normalized_score = (
#         rhyme_score * RHYME_WEIGHT +
#         diversity_score * DIVERSITY_WEIGHT +
#         sentiment_score * SENTIMENT_WEIGHT +
#         complexity_score * COMPLEXITY_WEIGHT
#     )
#
#     # 3. Scale the final score to be between 0 and 10.
#     final_score = final_normalized_score * 10
#
#     return round(final_score, 1)
#
#
# def main():
#     """Main function to demonstrate the verse rater."""
#     print("🎵 Music Verse Rater 🎵")
#     print("-------------------------")
#
#     # --- Example Demonstrations ---
#     verse_1 = """
#     The sun is high, the sky is blue
#     And all I want is to be with you
#     The day is bright, a lovely sight
#     Everything just feels so right
#     """
#
#     verse_2 = """
#     I walk the line
#     I'm feeling fine
#     """
#
#     verse_3 = """
#     The cat sat on the mat
#     The dog chased the cat
#     The boy threw the ball
#     The girl stood by the wall
#     """
#
#     verse_4 = """
#     Existential dread permeates the conscious substrate
#     A silent symphony of what we can't articulate
#     Chasing fleeting phantoms in a world subordinate
#     To entropy's decree, we seal our own dark fate
#     """
#
#     print(f"Verse 1 (Simple AABB Rhyme):\n{verse_1.strip()}\nRating: {rate_verse(verse_1)} / 10\n")
#     print(f"Verse 2 (Very Short):\n{verse_2.strip()}\nRating: {rate_verse(verse_2)} / 10\n")
#     print(f"Verse 3 (No Rhyme, Simple Vocab):\n{verse_3.strip()}\nRating: {rate_verse(verse_3)} / 10\n")
#     print(f"Verse 4 (Complex & Rhyming):\n{verse_4.strip()}\nRating: {rate_verse(verse_4)} / 10\n")
#
#     # --- Interactive Mode ---
#     print("-------------------------")
#     print("Enter your own verse below. Type 'quit' on a new line to exit.")
#
#     while True:
#         user_lines = []
#         print("\nEnter verse (press Enter twice to finish):")
#         while True:
#             try:
#                 line = input()
#                 if not line:
#                     break
#                 if line.lower() == 'quit':
#                     print("Exiting. Goodbye!")
#                     return
#                 user_lines.append(line)
#             except EOFError:
#                 break # End of input
#
#         user_verse = "\n".join(user_lines)
#         if user_verse.strip():
#             rating = rate_verse(user_verse)
#             print(f"\n✨ Your verse rating is: {rating} / 10")
#         elif not user_lines or user_lines[0].lower() != 'quit':
#             print("No verse entered. Try again or type 'quit' to exit.")
#
#         if not user_lines: # Break outer loop if input was empty and not quitting
#             break
#
#
# if __name__ == "__main__":
#     main()
